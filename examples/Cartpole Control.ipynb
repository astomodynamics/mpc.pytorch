# %%
import torch
import sys 
sys.path.append('/home/tom/github/mpc.pytorch')

from mpc import mpc
from mpc.mpc import QuadCost, LinDx, GradMethods
from mpc.env_dx import cartpole

import numpy as np
import numpy.random as npr

import matplotlib.pyplot as plt

import os
import io
import base64
import tempfile
from IPython.display import HTML

from tqdm import tqdm

# %matplotlib inline

# %%
dx = cartpole.CartpoleDx()

n_batch, T, mpc_T = 8, 100, 25

def uniform(shape, low, high):
    r = high-low
    return torch.rand(shape)*r+low

torch.manual_seed(0)
th = uniform(n_batch, -2*np.pi, 2*np.pi)
thdot = uniform(n_batch, -.5, .5)
x = uniform(n_batch, -0.5, 0.5)
xdot = uniform(n_batch, -0.5, 0.5)
xinit = torch.stack((x, xdot, torch.cos(th), torch.sin(th), thdot), dim=1)

x = xinit
u_init = None

q, p = dx.get_true_obj()
Q = torch.diag(q).unsqueeze(0).unsqueeze(0).repeat(
    mpc_T, n_batch, 1, 1
)
p = p.unsqueeze(0).repeat(mpc_T, n_batch, 1)

t_dir = tempfile.mkdtemp()
print('Tmp dir: {}'.format(t_dir))

action_history = []
for t in tqdm(range(T)):
    nominal_states, nominal_actions, nominal_objs = mpc.MPC(
        dx.n_state, dx.n_ctrl, mpc_T,
        u_init=u_init,
        u_lower=dx.lower, u_upper=dx.upper,
        lqr_iter=50,
        verbose=0,
        exit_unconverged=False,
        detach_unconverged=False,
        linesearch_decay=dx.linesearch_decay,
        max_linesearch_iter=dx.max_linesearch_iter,
        grad_method=GradMethods.AUTO_DIFF,
        eps=1e-2,
    )(x, QuadCost(Q, p), dx)
    
    next_action = nominal_actions[0]
    action_history.append(next_action)
    u_init = torch.cat((nominal_actions[1:], torch.zeros(1, n_batch, dx.n_ctrl)), dim=0)
    u_init[-2] = u_init[-3]
    x = dx(x, next_action)

    n_col = 4
    n_row = n_batch // n_col
    fig, axs = plt.subplots(n_row, n_col, figsize=(3*n_col,3*n_row), gridspec_kw = {'wspace':0, 'hspace':0})
    axs = axs.reshape(-1)
    for i in range(n_batch):
        dx.get_frame(x[i], ax=axs[i])
        axs[i].get_xaxis().set_visible(False)
        axs[i].get_yaxis().set_visible(False)
    fig.tight_layout()
    fig.savefig(os.path.join(t_dir, 'frame_{:03d}.png'.format(t)))
    plt.close(fig)
    
action_history = torch.stack(action_history).detach()[:,:,0]
# Out:
# Tmp dir: /tmp/tmpih3_hqqj
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:34<00:00,  2.93it/s]

# %%
# Plot actions
for t in tqdm(range(T)):
    fig, axs = plt.subplots(n_row, n_col, figsize=(3*n_col,3*n_row), gridspec_kw = {'wspace':0, 'hspace':0})
    axs = axs.reshape(-1)
    for i in range(n_batch):
        axs[i].plot(action_history[:,i], color='k')
        axs[i].set_ylim(-15, 15)
        axs[i].axvline(t, color='k', ls='--', linewidth=4)
        axs[i].get_xaxis().set_visible(False)
        axs[i].get_yaxis().set_visible(False)
    fig.tight_layout()
    fig.savefig(os.path.join(t_dir, 'actions_{:03d}.png'.format(t)))
    plt.close(fig)
    
    f1 = os.path.join(t_dir, 'frame_{:03d}.png'.format(t))
    f2 = os.path.join(t_dir, 'actions_{:03d}.png'.format(t))
    f_out = os.path.join(t_dir, '{:03d}.png'.format(t))
    os.system(f'convert {f1} {f2} +append -resize 1200x {f_out}')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#   2%|▏         | 2/100 [00:00<00:09, 10.41it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#   4%|▍         | 4/100 [00:00<00:09, 10.53it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#   6%|▌         | 6/100 [00:00<00:09, 10.38it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#   8%|▊         | 8/100 [00:00<00:08, 10.34it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  10%|█         | 10/100 [00:00<00:08, 10.47it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  12%|█▏        | 12/100 [00:01<00:08, 10.49it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  14%|█▍        | 14/100 [00:01<00:08, 10.56it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  16%|█▌        | 16/100 [00:01<00:07, 10.59it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  18%|█▊        | 18/100 [00:01<00:07, 10.59it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  20%|██        | 20/100 [00:03<00:21,  3.69it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  22%|██▏       | 22/100 [00:03<00:16,  4.61it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  24%|██▍       | 24/100 [00:03<00:13,  5.56it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  26%|██▌       | 26/100 [00:03<00:11,  6.51it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  28%|██▊       | 28/100 [00:03<00:09,  7.38it/s]sh: 1: convert: not found
#  29%|██▉       | 29/100 [00:04<00:11,  6.09it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  31%|███       | 31/100 [00:04<00:09,  7.14it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  33%|███▎      | 33/100 [00:04<00:08,  7.99it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  35%|███▌      | 35/100 [00:04<00:07,  8.68it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  37%|███▋      | 37/100 [00:04<00:06,  9.20it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  39%|███▉      | 39/100 [00:05<00:06,  9.53it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  41%|████      | 41/100 [00:05<00:06,  9.81it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  43%|████▎     | 43/100 [00:05<00:08,  6.98it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  45%|████▌     | 45/100 [00:05<00:07,  7.77it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  47%|████▋     | 47/100 [00:06<00:06,  8.47it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  49%|████▉     | 49/100 [00:06<00:05,  8.99it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  51%|█████     | 51/100 [00:06<00:05,  9.44it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  53%|█████▎    | 53/100 [00:06<00:04,  9.71it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  55%|█████▌    | 55/100 [00:06<00:04,  9.97it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  57%|█████▋    | 57/100 [00:07<00:07,  5.91it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  59%|█████▉    | 59/100 [00:07<00:06,  6.76it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  61%|██████    | 61/100 [00:07<00:05,  7.56it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  63%|██████▎   | 63/100 [00:08<00:04,  8.30it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  65%|██████▌   | 65/100 [00:08<00:03,  8.90it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  67%|██████▋   | 67/100 [00:08<00:03,  9.40it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  69%|██████▉   | 69/100 [00:08<00:03,  9.65it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  71%|███████   | 71/100 [00:08<00:02,  9.96it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  73%|███████▎  | 73/100 [00:09<00:02, 10.09it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  75%|███████▌  | 75/100 [00:09<00:02, 10.19it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  77%|███████▋  | 77/100 [00:09<00:03,  5.92it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  79%|███████▉  | 79/100 [00:10<00:03,  6.85it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  81%|████████  | 81/100 [00:10<00:02,  7.69it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  83%|████████▎ | 83/100 [00:10<00:02,  8.35it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  85%|████████▌ | 85/100 [00:10<00:01,  8.97it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  87%|████████▋ | 87/100 [00:10<00:01,  9.44it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  89%|████████▉ | 89/100 [00:10<00:01,  9.76it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  91%|█████████ | 91/100 [00:11<00:00,  9.98it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  93%|█████████▎| 93/100 [00:11<00:00, 10.19it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  95%|█████████▌| 95/100 [00:11<00:00, 10.28it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  97%|█████████▋| 97/100 [00:11<00:00, 10.30it/s]sh: 1: convert: not found
# sh: 1: convert: not found
#  99%|█████████▉| 99/100 [00:11<00:00, 10.33it/s]sh: 1: convert: not found
# 100%|██████████| 100/100 [00:12<00:00,  7.87it/s]

# %%
vid_fname = 'cartpole.mp4'

if os.path.exists(vid_fname):
    os.remove(vid_fname)
    
cmd = 'ffmpeg -r 16 -f image2 -i {}/%03d.png -vcodec libx264 -crf 25 -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -pix_fmt yuv420p {}'.format(
    t_dir, vid_fname
)
os.system(cmd)
print('Saving video to: {}'.format(vid_fname))
# Out:
# Saving video to: cartpole.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [image2 @ 0x5c154eeb8b40] Could find no file with path '/tmp/tmpih3_hqqj/%03d.png' and index in the range 0-4
# /tmp/tmpih3_hqqj/%03d.png: No such file or directory

# %%
video = io.open(vid_fname, 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
